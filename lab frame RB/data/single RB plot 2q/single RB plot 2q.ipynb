# %%
import pickle
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import math
import numpy as np

# %%
with open('1000_2q.pkl', 'rb') as f:
    data = pickle.load(f)
f.close()

F = data[1]
###############
# SRB with fixed B

def func(x, A, B, r):
    return A * (1 - 4 / 3 * r) ** x + B

l1 = np.arange(1, 20, 2)
l2 = np.arange(20, 100, 10)
L = np.hstack((l1, l2))
popt, pcov = curve_fit(func, L, F, p0=[1, 1, 0], bounds=(0, 1), maxfev=5000)
print("F_Ciff = 1 - r = ", (1 - popt[2]) * 100)
print("A = ", popt[0])
print("B = ", popt[1])

plt.plot(L, F, 'o', markersize=4)
plt.plot(L, func(L, *popt), 'r-')
plt.ylim(top=1.0)
plt.xlabel("Number of Cliffords (L)")
plt.ylabel("Proj. State Prob.")
plt.show()
# Out:
# F_Ciff = 1 - r =  99.90294736833273
# A =  0.9598106078655684
# B =  9.124040521953728e-14

# %%
with open('1000_2q.pkl', 'rb') as f:
    data = pickle.load(f)
f.close()

F = data[1]
###############
# SRB with fixed B

def func(x, A, r):
    return A * (1 - 4 / 3 * r) ** x + 0.25

l1 = np.arange(1, 20, 2)
l2 = np.arange(20, 100, 10)
L = np.hstack((l1, l2))
popt, pcov = curve_fit(func, L, F, p0=[1, 0], bounds=(0, 1), maxfev=5000)
print("F_Ciff = 1 - r = ", (1 - popt[1]) * 100)
print("A = ", popt[0])

plt.plot(L, F, 'o', markersize=4)
plt.plot(L, func(L, *popt), 'r-')
plt.ylim(top=1.0)
plt.xlabel("Number of Cliffords (L)")
plt.ylabel("Proj. State Prob.")
plt.show()
# Out:
# F_Ciff = 1 - r =  99.86616990742326
# A =  0.7100653124958065

# %%
with open('25000_2q.pkl', 'rb') as f:
    data = pickle.load(f)
f.close()

F = data[1]
###############
# SRB with fixed B

def func(x, b, a):
    return 3/4 * 2.71828 ** (-(b*x)**a) + 1/4

l1 = np.arange(1, 20, 2)
l2 = np.arange(20, 100, 10)
L = np.hstack((l1, l2))
popt, pcov = curve_fit(func, L, F, p0=[1, 1], bounds=(0, 1), maxfev=5000)
print(popt)
print("F_Ciff = ", (1 - popt[0]) * 100)

plt.plot(L, F, 'o', markersize=4)
plt.plot(L, func(L, *popt), 'r-')
plt.ylim(top=1.0)
plt.xlabel("Number of Cliffords (L)")
plt.ylabel("Proj. State Prob.")
plt.show()
# Out:
# [0.04106432 0.48490471]
# F_Ciff =  95.89356756204918
